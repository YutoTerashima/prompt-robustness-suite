# %% [markdown]
# # Prompt Robustness Suite walkthrough\n\nResearch question: Which prompt policies survive realistic perturbations without destroying benign pass rate?\n

# %% [markdown]
# ## What to inspect\n\n- README result table\n- `reports/results/experiment_index.json`\n- `reports/prompt_robustness_v2_research_report.md`\n- maturity review report\n

# %%
from pathlib import Path\nimport json\nroot = Path('..').resolve()\nindex_path = root / 'reports' / 'results' / 'experiment_index.json'\nif index_path.exists():\n    index = json.loads(index_path.read_text())\n    print(index.get('title'))\n    print('results:', len(index.get('results', [])))\n    print('artifacts:', len(index.get('artifacts', [])))\nelse:\n    print('Showcase/archive repo: inspect reports and notebooks directly.')\n

# %% [markdown]
# ## Interpretation\n\n- Typoglycemia and base64-like wrappers expose brittle keyword policies.\n- Instruction-sandwich perturbations reveal overblocking risk.\n- The project turns prompt changes into measurable regression gates.\n
